# %%
from datasets import Dataset
from huggingface_hub import HfApi
from datasets import load_dataset
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from datasets import Dataset
#       2 from huggingface_hub import HfApi
#       3 from datasets import load_dataset
#
# ModuleNotFoundError: No module named 'datasets'

# %% [markdown]
# ## Load HF Datasets

# %%
book_genres = load_dataset("ada-datadruids/book_genres")
wiki_book_movie_ids_matching = load_dataset("ada-datadruids/wiki_book_movie_ids_matching")
TMDB_movie_dataset_reduced = load_dataset("ada-datadruids/TMDB_movie_dataset_reduced")
plot_summaries = load_dataset("ada-datadruids/plot_summaries")
movies = load_dataset("ada-datadruids/movies")
movie_metadata = load_dataset("ada-datadruids/movie-metadata")
merged_movies_books_cleaned = load_dataset("ada-datadruids/merged_movies_books_cleaned")
CPIAUCNS = load_dataset("ada-datadruids/CPIAUCNS")
booksummaries_cleaned = load_dataset("ada-datadruids/booksummaries_cleaned")
booksmovies = load_dataset("ada-datadruids/booksmovies")
books = load_dataset("ada-datadruids/books")
bookfilm_summaries_with_similarity_and_sentiment = load_dataset("ada-datadruids/bookfilm_summaries_with_similarity_and_sentiment")

# %% [markdown]
# ## Refactor Datasets to Dataframes

# %%
book_genres_df = book_genres['train'].to_pandas()
wiki_book_movie_ids_matching_df = wiki_book_movie_ids_matching['train'].to_pandas()
TMDB_movie_dataset_reduced_df = TMDB_movie_dataset_reduced['train'].to_pandas()
plot_summaries_df = plot_summaries['train'].to_pandas()
movies_df = movies['train'].to_pandas()
movie_metadata_df = movie_metadata['train'].to_pandas()
merged_movies_books_cleaned_df = merged_movies_books_cleaned['train'].to_pandas()
CPIAUCNS_df = CPIAUCNS['train'].to_pandas()
booksummaries_cleaned_df = booksummaries_cleaned['train'].to_pandas()
booksmovies_df = booksmovies['train'].to_pandas()
books_df = books['train'].to_pandas()
bookfilm_summaries_with_similarity_and_sentiment_df = bookfilm_summaries_with_similarity_and_sentiment['train'].to_pandas()

# %% [markdown]
# ## Display Dataframes

# %%
book_genres_df.to_csv('../../data/book_genres.csv', index=False)
wiki_book_movie_ids_matching_df.to_csv('../../data/wiki_book_movie_ids_matching.csv', index = False)
TMDB_movie_dataset_reduced_df.to_csv('../../data/TMDB_movie_dataset_reduced.csv', index=True)
plot_summaries_df.to_csv('../../data/plot_summaries.csv', index=True)
movies_df.to_csv('../../data/movies.csv', index=True)
movie_metadata_df.to_csv('../../data/movie_metadata.tsv','\t', index=True)
merged_movies_books_cleaned_df.to_csv('../../data/merged_movies_books_cleaned.csv', index=True)
CPIAUCNS_df.to_csv('../../data/CPIAUCNS.csv', index=True)
booksummaries_cleaned_df.to_csv('../../data/booksummaries_cleaned.csv', index=True)
bookfilm_summaries_with_similarity_and_sentiment_df.to_csv('../../data/bookfilm_summaries_with_similarity_and_sentiment.csv', index=True)
books_df.to_csv('../../data/books.csv', index=True)
booksmovies_df.to_csv('../../data/booksmovies.csv', index=True)
# Out:
#    book_id           genre  possible_filter
# 0   915001         Fiction                0
# 1   915001  Womens Fiction                1
# 2   915001           Drama                0
# 3   915001         Romance                1
# 4  7199539      Historical                1
#    index  id               BookTitle  BookYear          Author  \
# 0      0   3              De Aanslag      1982   Harry Mulisch
# 1      1   4             About a Boy      1998     Nick Hornby
# 2      2   5           About Schmidt      1996    Louis Begley
# 3      3   6          Absolute Power      1996  David Baldacci
# 4      4   7  The Accidental Tourist      1985      Anne Tyler
#
#                 FilmTitle  FilmYear                    full name  tmdb_id  \
# 0             The Assault      1986             The Assault 1986     2753
# 1             About a Boy      2002             About a Boy 2002      245
# 2           About Schmidt      2002           About Schmidt 2002     2755
# 3          Absolute Power      1997          Absolute Power 1997       66
# 4  The Accidental Tourist      1988  The Accidental Tourist 1988    31052
#
#    id_goodreads     imdbid
# 0       1964904  tt0090576
# 1       2770004  tt0276751
# 2        908745  tt0257360
# 3        760769  tt0118548
# 4         60792  tt0094606
#    Unnamed: 0     imdbid     revenue
# 0           0  tt1375666   825532764
# 1           1  tt0816692   701729206
# 2           2  tt0468569  1004558444
# 3           3  tt0499549  2923706026
# 4           4  tt0848228  1518815515
#                                                 text
# 0  23890098\tShlykov, a hard-working taxi driver ...
# 1  31186339\tThe nation of Panem consists of a we...
# 2  20663735\tPoovalli Induchoodan  is sentenced f...
# 3  2231378\tThe Lemon Drop Kid , a New York City ...
# 4  595909\tSeventh-day Adventist Church pastor Mi...
#       imdbid    book_id                   title          author    year  \
# 0  tt0090576  1964904.0              De Aanslag   Harry Mulisch  1986.0
# 1  tt0276751  2770004.0             About a Boy     Nick Hornby  2002.0
# 2  tt0257360   908745.0           About Schmidt    Louis Begley  2002.0
# 3  tt0118548   760769.0          Absolute Power  David Baldacci  1997.0
# 4  tt0094606    60792.0  The Accidental Tourist      Anne Tyler  1988.0
#
#                      full_name    budget    revenue  runtime  \
# 0             The Assault 1986         0     203781    124.0
# 1             About a Boy 2002  27000000  129000000    101.0
# 2           About Schmidt 2002  30000000  105834556    125.0
# 3          Absolute Power 1997  50000000   50068310    121.0
# 4  The Accidental Tourist 1988         0          0    121.0
#
#                         poster_path  rating_average  vote_count  \
# 0  /roLUdrbcpFiWjIqs2NbpItR74KE.jpg             7.3      2823.0
# 1  /1kz4Q2v7cxwNnTfkjrujzWAVCne.jpg             7.1    158912.0
# 2  /riJV5Bq0IXItG3ceywNWkw7il7K.jpg             7.2    116379.0
# 3  /oJQdp09Oc51DkArsMDvgDLdWiDu.jpg             6.7     45519.0
# 4  /dyk2BqPajLRBpVQ6jsSJJdgfuXe.jpg             6.8     13738.0
#
#    standardized_rating  normalized_rating  goodreads_scale_rating
# 0             0.768571           0.732394                    3.65
# 1             0.570745           0.704225                    3.55
# 2             0.669658           0.718310                    3.60
# 3             0.175092           0.647887                    3.35
# 4             0.274005           0.661972                    3.40
#      975900   /m/03vyhn                                     Ghosts of Mars  \
# 0   3196793   /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
# 1  28463795  /m/0crgdbh                                        Brun bitter
# 2   9363483  /m/0285_cd                                   White Of The Eye
# 3    261236   /m/01mrr1                                  A Woman in Flames
# 4  13696889  /m/03cfc81                                      The Gangsters
#
#    2001-08-24  14010832   98.0  \
# 0  2000-02-16       NaN   95.0
# 1        1988       NaN   83.0
# 2        1987       NaN  110.0
# 3        1983       NaN  106.0
# 4  1913-05-29       NaN   35.0
#
#                   {"/m/02h40lc": "English Language"}  \
# 0                 {"/m/02h40lc": "English Language"}
# 1                 {"/m/05f_3": "Norwegian Language"}
# 2                 {"/m/02h40lc": "English Language"}
# 3                  {"/m/04306rv": "German Language"}
# 4  {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
#
#    {"/m/09c7w0": "United States of America"}  \
# 0  {"/m/09c7w0": "United States of America"}
# 1                     {"/m/05b4w": "Norway"}
# 2             {"/m/07ssc": "United Kingdom"}
# 3                    {"/m/0345h": "Germany"}
# 4  {"/m/09c7w0": "United States of America"}
#
#   {"/m/01jfsb": "Thriller", "/m/06n90": "Science Fiction", "/m/03npn": "Horror", "/m/03k9fj": "Adventure", "/m/0fdjb": "Supernatural", "/m/02kdv5l": "Action", "/m/09zvmj": "Space western"}
# 0  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 1  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 2  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 3                            {"/m/07s9rl0": "Drama"}
# 4  {"/m/02hmvc": "Short Film", "/m/06ppq": "Silen...
#    Unnamed: 0  movie_id movie_cluster         movie_name release_date  \
# 0           0     77856      /m/0kcn7       Mary Poppins   1964-08-27
# 1           1   1369204     /m/04x8zs             Juarez         1939
# 2           2    164388     /m/015wmt  The Great Santini   1979-10-26
# 3           3  19095614    /m/04yc5nd         The Castle         1968
# 4           4  13613357    /m/03cbvzw       Grand Canary   1934-07-20
#
#         budget  runtime_x                                           language  \
# 0  102272727.0      139.0                 {"/m/02h40lc": "English Language"}
# 1          NaN      125.0  {"/m/02h40lc": "English Language", "/m/06nm1":...
# 2    4702575.0      115.0                 {"/m/02h40lc": "English Language"}
# 3          NaN       88.0                  {"/m/04306rv": "German Language"}
# 4          NaN       78.0                 {"/m/02h40lc": "English Language"}
#
#                                      country  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2  {"/m/09c7w0": "United States of America"}
# 3               {"/m/082fr": "West Germany"}
# 4  {"/m/09c7w0": "United States of America"}
#
#                                               genres  ...  index    id  \
# 0  {"/m/0hj3myq": "Children's/Family", "/m/04t36"...  ...   1279  1855
# 1  {"/m/04xvh5": "Costume drama", "/m/03bxz7": "B...  ...   1504  2217
# 2  {"/m/02h8pkk": "Family Drama", "/m/07s9rl0": "...  ...    883  1253
# 3    {"/m/02n4kr": "Mystery", "/m/07s9rl0": "Drama"}  ...    395   564
# 4  {"/m/02l7c8": "Romance Film", "/m/07s9rl0": "D...  ...    867  1229
#
#                                            BookTitle BookYear         Author  \
# 0                                       Mary Poppins     1934  P. L. Travers
# 1  The Phantom Crown: The Story of Maximilian & C...     1934              0
# 2                                  The Great Santini     1976     Pat Conroy
# 3                                         The Castle     1926    Franz Kafka
# 4                                       Grand Canary     1933   A. J. Cronin
#
#                 full name tmdb_id  id_goodreads     imdbid runtime_y
# 0       Mary Poppins 1964     433        152380  tt0058331     139.0
# 1             Juarez 1939   78318      10546105  tt0031516     125.0
# 2  The Great Santini 1979   21887       1110004  tt0079239     115.0
# 3         The Castle 1968  197962        152864  tt0063563      93.0
# 4       Grand Canary 1934  432684      37941573  tt0025196      78.0
#
# [5 rows x 21 columns]
#          DATE  CPIAUCNS
# 0  1913-01-01       9.8
# 1  1913-02-01       9.8
# 2  1913-03-01       9.8
# 3  1913-04-01       9.8
# 4  1913-05-01       9.7
#      Id     Code                                      Title           Author  \
# 0   620  /m/0hhy                                Animal Farm    George Orwell
# 1   843  /m/0k36                         A Clockwork Orange  Anthony Burgess
# 2   986  /m/0ldx                                 The Plague     Albert Camus
# 3  1756  /m/0sww  An Enquiry Concerning Human Understanding       David Hume
# 4  2080  /m/0wkt                       A Fire Upon the Deep     Vernor Vinge
#
#         Data                                             Genres  \
# 0  8/17/1945  {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1       1962  {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2       1947  {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 3       None                                               None
# 4       None  {"/m/03lrw": "Hard science fiction", "/m/06n90...
#
#                                              Summary
# 0   Old Major, the old boar on the Manor Farm, ca...
# 1   Alex, a teenager living in near-future Englan...
# 2   The text of The Plague is divided into five p...
# 3   The argument of the Enquiry proceeds by a ser...
# 4   The novel posits that space around the Milky ...
#    id           BookTitle BookAltTitle  BookYear                   BookLink  \
# 0   0  The A.B.C. Murders         None      1936   /wiki/The_A.B.C._Murders
# 1   1  The A.B.C. Murders         None      1936   /wiki/The_A.B.C._Murders
# 2   2         À ton image         None      1998                       None
# 3   3          De Aanslag  The Assault      1982           /wiki/De_Aanslag
# 4   4         About a Boy         None      1998  /wiki/About_a_Boy_(novel)
#
#                 Author             FilmTitle  \
# 0      Agatha Christie  The Alphabet Murders
# 1      Agatha Christie    The A.B.C. Murders
# 2  Louise L. Lambrichs           À ton image
# 3        Harry Mulisch           The Assault
# 4          Nick Hornby           About a Boy
#
#                                             FilmLink  FilmYear  \
# 0                         /wiki/The_Alphabet_Murders      1966
# 1  /wiki/List_of_Agatha_Christie%27s_Poirot_episo...      1992
# 2                             /wiki/%C3%80_ton_image      2004
# 3                           /wiki/The_Assault_(film)      1986
# 4                           /wiki/About_a_Boy_(film)      2002
#
#                 ISBN
# 0  978-1-57912-624-7
# 1  978-1-57912-624-7
# 2               None
# 3      0-394-54245-2
# 4      0-575-06159-6
#       book_id                                    title  year  avg_rating  \
# 0   1964904.0                              The Assault  1982        3.71
# 1   2770004.0                              About A Boy  1998        3.80
# 2   1171639.0                               Adams Fall  2000        3.28
# 3     56649.0                          The Adventurers  1966        3.87
# 4  41096625.0  The Adventures of Hajji Baba of Ispahan  1824        4.29
#
#    rating_count  review_count series series_num                  author  \
# 0        9367.0         390.0   None       None           Harry Mulisch
# 1      117323.0        3027.0   None       None             Nick Hornby
# 2          88.0          12.0   None       None            Sean Desmond
# 3        1313.0          51.0   None       None          Harold Robbins
# 4           7.0           2.0   None       None  James Justinian Morier
#
#                                          description  length  five_stars  \
# 0  It is the winter of 1945, the last dark days o...   185.0      1736.0
# 1  'How cool was Will Freeman'Too cool! At thirty...   286.0     24807.0
# 2  With the fall of his senior year at the Colleg...   272.0        15.0
# 3  From the author of The New York Times #1 best-...   712.0       389.0
# 4  The Adventures of Hajji Baba of Ispahan by Jam...   750.0         3.0
#
#    four_stars  three_stars  two_stars  one_star  \
# 0      4093.0       2734.0      648.0     156.0
# 1     51876.0      33618.0     5850.0    1172.0
# 2        22.0         31.0       13.0       7.0
# 3       486.0        340.0       80.0      18.0
# 4         3.0          1.0        0.0       0.0
#
#                                          cover_image  standardized_rating  \
# 0  https://images.gr-assets.com/books/1547811518l...            -0.471058
# 1  https://images.gr-assets.com/books/1347049451l...            -0.158221
# 2  https://images.gr-assets.com/books/1311998318l...            -1.965724
# 3  https://images.gr-assets.com/books/1411687302l...             0.085097
# 4  https://images.gr-assets.com/books/1534260697l...             1.545003
#
#    normalized_rating
# 0           0.570000
# 1           0.600000
# 2           0.426667
# 3           0.623333
# 4           0.763333
#    movie_id                    book_title  \
# 0    196176  The Siege of Trencher's Farm
# 1   6703617           Journey to the West
# 2  24416479              The Beast Master
# 3   9384481                  The Blessing
# 4  22224559                 The Last Song
#
#                                   movie_name  \
# 0                                 Straw Dogs
# 1                      The Forbidden Kingdom
# 2  Beastmaster 2: Through the Portal of Time
# 3                       Count Your Blessings
# 4                              The Last Song
#
#                                         book_summary  \
# 0   George Magruder, an American professor of Eng...
# 1   The novel has 100 chapters. These can be divi...
# 2   It tells the story of Hosteen Storm, an ex-so...
# 3   It is set in the post-war World War II period...
# 4   Veronica “Ronnie” Miller’s life was turned up...
#
#                                         film_summary  similarity  \
# 0  David Sumner , a timid American mathematician,...    0.451876
# 1  In this film, which is based loosely on the an...    0.559594
# 2  Dar, the Beastmaster , is back and now he has ...    0.344548
# 3  While visiting Grace Allingham in wartime Lond...    0.669707
# 4  At seventeen, Veronica "Ronnie" Miller  remain...    0.852735
#
#   film_sentiment  film_sentiment_score book_sentiment  book_sentiment_score
# 0       positive              0.333608       positive              0.994480
# 1       positive              0.995482       positive              0.995404
# 2       positive              0.997562       positive              0.998812
# 3       positive              0.996070       positive              0.996607
# 4       positive              0.978184       positive              0.998164
